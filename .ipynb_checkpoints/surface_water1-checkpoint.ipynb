# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
df = pd.read_csv('Surface_Drinking_Water_Importance__Feature_Layer_.csv')
us_geo = gpd.read_file('images/us_geo.json')

# %%
df_co = df[(df['HUC_12'] >= 140000000000) & (df['HUC_12'] < 160000000000)]
df_co
# Out:
#              HUC_12                      HU_12_NAME  IMP1  IN_FOR2  IN_PRONF2  \
# 56476  140300030402                      McKee Draw    20    15.40      10.80
# 56477  140300030403                     Callan Draw    21    18.90      15.75
# 56478  140300030404       McKee Draw-Naturita Creek    25    22.75      21.75
# 56479  140300030405        Headwaters Maverick Draw    54    32.40       5.94
# 56480  140300030406            Outlet Maverick Draw    20    10.40       5.40
# ...             ...                             ...   ...      ...        ...
# 72025  150801010302                Presumido Canyon     0     0.00       0.00
# 72026  150801010303       Coyote Canyon-Vamori Wash     0     0.00       0.00
# 72027  150801010304                Chutum Vaya Wash     0     0.00       0.00
# 72028  150801010305  Baboquivari Valley-Vamori Wash     0     0.00       0.00
# 72120  150801010306                    150801010306     0     0.00       0.00
#
#        IN_NFS2  IN_PRI2  INS_FOR3  DEV_FOR3  FIR_FOR3  ...  PER_PRONF2  \
# 56476     9.20     4.60   0.00000   1.41372  14.59920  ...          54
# 56477     8.82     3.15   1.82196   6.78321  17.39745  ...          75
# 56478    11.00     1.00   1.72900   0.00000  18.92800  ...          87
# 56479     2.70    26.46   0.00000   3.18168  29.21832  ...          11
# 56480     0.00     5.00   0.00000   0.32656  10.21696  ...          27
# ...        ...      ...       ...       ...       ...  ...         ...
# 72025     0.00     0.00   0.00000   0.00000   0.00000  ...           0
# 72026     0.00     0.00   0.00000   0.00000   0.00000  ...           0
# 72027     0.00     0.00   0.00000   0.00000   0.00000  ...           7
# 72028     0.00     0.00   0.00000   0.00000   0.00000  ...           0
# 72120     0.00     0.00   0.00000   0.00000   0.00000  ...           0
#
#        PER_NFS2  PER_PRI2  PER_INSEC3  PER_DEV3  PER_FIRE3  OBJECTID  \
# 56476        46        23        0.00      9.18      94.80    257117
# 56477        42        15        9.64     35.89      92.05    257118
# 56478        44         4        7.60      0.00      83.20    257119
# 56479         5        49        0.00      9.82      90.18    257120
# 56480         0        25        0.00      3.14      98.24    257121
# ...         ...       ...         ...       ...        ...       ...
# 72025         0         0        0.00      0.00       0.00    272666
# 72026         0         0        0.00      0.00       0.00    272667
# 72027         0         0        0.00      0.00       0.00    272668
# 72028         0         0        0.00      0.00       0.00    272669
# 72120         0         0        0.00      0.00       0.00    272761
#
#        POPSERVED  SHAPEAREA  SHAPELEN
# 56476          0   0.004777  0.382179
# 56477          0   0.005458  0.436415
# 56478          0   0.004728  0.419833
# 56479       1700   0.012474  0.702822
# 56480          0   0.006414  0.488174
# ...          ...        ...       ...
# 72025          0   0.002375  0.247419
# 72026          0   0.013388  0.650764
# 72027          0   0.010541  0.676661
# 72028          0   0.018735  0.692013
# 72120          0   0.003138  0.526572
#
# [7003 rows x 22 columns]

# %%
pop = df[(df['HUC_12'] >= 140000000000) & (df['HUC_12'] < 160000000000) & (df['POPSERVED']>0)]

# %%
def zero_col(df, column, val):
    pass

# %%
fig, ax = plt.subplots(1, 4, figsize=(15, 10))
df_imp0 = df_co.loc[df_co['HUC_12'] < 150000000000,'IMP1']
df_lower = df_co.loc[df_co['HUC_12'] < 150000000000, 'HUC_12']
df_imp1 = df_co.loc[df_co['HUC_12'] >= 150000000000,'IMP1']
df_upper = df_co.loc[df_co['HUC_12'] >= 150000000000, 'HUC_12']
ax[0].scatter(df_lower, df_imp0)
ax[1].scatter(df_upper, df_imp1)
ax[0].set_title('Water Level Importance: Lower', size=14)
ax[1].set_title('Water Level Imporatnce: Upper', size=14)
ax[0].set_ylabel('Level of Importance', size=14)
co_mean = df_co['IMP1'].mean()
ax[0].axhline(co_mean)
ax[1].axhline(co_mean)


df_pop0 = pop.loc[pop['HUC_12'] < 150000000000,'IMP1']
df_lower_pop = pop.loc[pop['HUC_12'] < 150000000000, 'HUC_12']
df_pop1 = pop.loc[pop['HUC_12'] >= 150000000000,'IMP1']
df_upper_pop = pop.loc[pop['HUC_12'] >= 150000000000, 'HUC_12']
ax[2].scatter(df_lower_pop, df_pop0, color='green')
ax[3].scatter(df_upper_pop, df_pop1, color='green')
ax[2].set_title('Population Served: Lower', size=14, color='green')
ax[3].set_title('Population Served: Upper', size=14, color='green')
ax[2].set_ylabel('Level of High Importance for Population', size=14, color='green')
pop_mean = pop['IMP1'].mean()
ax[2].axhline(pop_mean)
ax[3].axhline(pop_mean)
plt.tight_layout()

# %%
df_co[]
