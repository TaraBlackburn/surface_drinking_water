# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import plotly as py
import plotly.graph_objs as go

# %%
df1 = pd.read_csv('../data/Surface_Drinking_Water_Importance__Feature_Layer_.csv')

# %%
df1.head()
# Out:
#         HUC_12                    HU_12_NAME  IMP1  IN_FOR2  IN_PRONF2  \
# 0  10100081107  Patrick Brook-St. John River    69    42.09        0.0
# 1  10100081108   Gagnon Brook-St. John River    71    40.47        0.0
# 2  10100090101    West Branch Iroquois River     0     0.00        0.0
# 3  10100090102           East Iroquois River     0     0.00        0.0
# 4  10100090103                Iroquois River     0     0.00        0.0
#
#    IN_NFS2  IN_PRI2  INS_FOR3  DEV_FOR3  FIR_FOR3  ...  PER_PRONF2  PER_NFS2  \
# 0      0.0    42.09       0.0   3.84282       0.0  ...           0         0
# 1      0.0    40.47       0.0   2.27441       0.0  ...           0         0
# 2      0.0     0.00       0.0   0.00000       0.0  ...           0         0
# 3      0.0     0.00       0.0   0.00000       0.0  ...           0         0
# 4      0.0     0.00       0.0   0.00000       0.0  ...           0         0
#
#    PER_PRI2  PER_INSEC3  PER_DEV3  PER_FIRE3  OBJECTID  POPSERVED  SHAPEAREA  \
# 0        61         0.0      9.13        0.0    200641          0   0.017499
# 1        57         0.0      5.62        0.0    200642       2840   0.014860
# 2         0         0.0      0.00        0.0    200643          0   0.015546
# 3         0         0.0      0.00        0.0    200644          0   0.006054
# 4         0         0.0      0.00        0.0    200645          0   0.010037
#
#    SHAPELEN
# 0  1.022829
# 1  0.773298
# 2  0.771746
# 3  0.526763
# 4  0.555496
#
# [5 rows x 22 columns]

# %%
pd.plotting.scatter_matrix(df1, figsize=(10, 10));
